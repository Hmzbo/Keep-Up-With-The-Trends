# %% [markdown]
# # Keep Up  With The Trends

# %% [markdown]
# **Installation steps with conda**
#
# 1. conda create -n kuwtt pyton=3.10.14
# 2. pip install -r requirements.txt
# 3. pip install torch==2.3.1 --index-url https://download.pytorch.org/whl/cu118
# 4. [Download](https://ollama.com/download), Install & Run Ollama

# %%
# verify that CUDA is available

import torch

cuda_available = torch.cuda.is_available()
print(f"CUDA available: {cuda_available}")
# Out:
# CUDA available: True

# %%
# Import necessary libraries

import time
import json
import re
import requests
import pandas as pd
import xmltodict
from tqdm.notebook import tqdm
from duckduckgo_search import DDGS
from pprint import pprint

# %% [markdown]
# ## Scraping Trends Data

# %%
def fetch_and_parse_xml(url):
    try:
        # Fetch the XML data
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes
        xml_data = response.content

        # Parse the XML data and convert it to a dictionary
        data_dict = xmltodict.parse(xml_data)
        return data_dict

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the XML data: {e}")
    except xmltodict.expat.ExpatError as e:
        print(f"Error parsing the XML data: {e}")

# %%
# URL for the XML data
rss_xml_url_daily = 'https://trends.google.fr/trends/trendingsearches/daily/rss?geo=US'
rss_xml_url_realtime = 'https://trends.google.com/trending/rss?geo=US'

# Fetch, parse, and print the XML data
trends_dict = fetch_and_parse_xml(rss_xml_url_realtime)

pprint(trends_dict)
# Out:
# {'rss': {'@version': '2.0',
#          '@xmlns:atom': 'http://www.w3.org/2005/Atom',
#          '@xmlns:ht': 'https://trends.google.com/trending/rss',
#          'channel': {'atom:link': {'@href': 'https://trends.google.com/trending/rss?geo=US',
#                                    '@rel': 'self',
#                                    '@type': 'application/rss+xml'},
#                      'description': 'Recent searches',
#                      'item': [{'description': None,
#                                'ht:approx_traffic': '500+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTql8i2IYcESG8Y4vPdeoM3rlxw-Lkq9l9d0o7YudZ0-vo5KjfLni_wxA2O08I',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'NBC '
#                                                                         'Sports',
#                                                  'ht:news_item_title': 'Fantasy '
#                                                                        'Football '
#                                                                        '2024: '
#                                                                        'Rotoworld '
#                                                                        'staff '
#                                                                        'most '
#                                                                        'drafted '
#                                                                        'players',
#                                                  'ht:news_item_url': 'https://www.nbcsports.com/fantasy/football/news/fantasy-football-2024-rotoworld-staff-most-drafted-players'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQfvwTxSgP6nioRSP_bv-Bj_Ra2iscuXhFJiB-UVZRnkaIRyySNREZgdcrw-uw',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'CBS '
#                                                                         'Sports',
#                                                  'ht:news_item_title': '2024 '
#                                                                        'Fantasy '
#                                                                        'football '
#                                                                        'draft '
#                                                                        'strategy: '
#                                                                        'Tiers, '
#                                                                        'cheat '
#                                                                        'sheets, '
#                                                                        'best '
#                                                                        'breakout \n'
#                                                                        'players, '
#                                                                        'deep '
#                                                                        'sleepers '
#                                                                        'by NFL '
#                                                                        'expert',
#                                                  'ht:news_item_url': 'https://www.cbssports.com/fantasy/football/news/2024-fantasy-football-draft-strategy-tiers-cheat-sheets-best-breakout-players-deep-sleepers-by-nfl-expert/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRDm6fKQ5LJG1_07u_Qte563UQUMb7dfjhpDTIbY0LoTNHaib8Xil0081lO9Ls',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'ESPN',
#                                                  'ht:news_item_title': "Don't "
#                                                                        'be '
#                                                                        'surprised '
#                                                                        'if ... '
#                                                                        ': '
#                                                                        'Fantasy '
#                                                                        'predictions '
#                                                                        'for '
#                                                                        '2024',
#                                                  'ht:news_item_url': 'https://www.espn.com/fantasy/football/story/_/id/41032720/2024-fantasy-football-rankings-draft-picks-predictions-surprises'}],
#                                'ht:picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTql8i2IYcESG8Y4vPdeoM3rlxw-Lkq9l9d0o7YudZ0-vo5KjfLni_wxA2O08I',
#                                'ht:picture_source': 'NBC Sports',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:40:00 -0700',
#                                'title': 'fantasy pros'},
#                               {'description': None,
#                                'ht:approx_traffic': '1000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSdNjXhejwPqwkPVC3LM3OHcQY8lnL47NqYzCfGkLmi-WIh7dwWDapixCvYZos',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Daily '
#                                                                         'Express',
#                                                  'ht:news_item_title': 'Carlos '
#                                                                        'Alcaraz '
#                                                                        'and '
#                                                                        'Nick '
#                                                                        "Kyrgios' "
#                                                                        'DMs to '
#                                                                        'each '
#                                                                        'other '
#                                                                        'emerge '
#                                                                        'after '
#                                                                        'US '
#                                                                        'Open \n'
#                                                                        'disaster',
#                                                  'ht:news_item_url': 'https://www.express.co.uk/sport/tennis/1942333/Carlos-Alcaraz-Nick-Kyrgios-Tennis-US-Open'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQeYhJsPmaq_XoURxSWWb4kez1Sumpp2Sbkr_5N56NqyMa5i29akNohjMJrSwE',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Sports '
#                                                                         'Illustrated',
#                                                  'ht:news_item_title': 'Nick '
#                                                                        'Kyrgios '
#                                                                        'Hilariously '
#                                                                        'Roasts '
#                                                                        'Carlos '
#                                                                        'Alcaraz’s '
#                                                                        'US '
#                                                                        'Open '
#                                                                        'Outfit',
#                                                  'ht:news_item_url': 'https://www.si.com/onsi/serve/style/nick-kyrgios-hilariously-roasts-carlos-alcaraz-us-open-outfit'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRpWJ0wuK54kL5gXxXiUoKNKpY8_z7n0OfdPCL6CpvvtPWEw3256R8hDDOy8WY',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Sportskeeda',
#                                                  'ht:news_item_title': '"Arms '
#                                                                        'are '
#                                                                        'sensational!" '
#                                                                        '- Nick '
#                                                                        'Kyrgios '
#                                                                        'gushes '
#                                                                        'over '
#                                                                        'Carlos '
#                                                                        "Alcaraz's "
#                                                                        'Nike \n'
#                                                                        '"singlet" '
#                                                                        'as '
#                                                                        'Spaniard '
#                                                                        'makes '
#                                                                        '"fear" '
#                                                                        'claim '
#                                                                        'about '
#                                                                        'wearing '
#                                                                        'sleeveless '
#                                                                        'outfit '
#                                                                        'at \n'
#                                                                        'US '
#                                                                        'Open',
#                                                  'ht:news_item_url': 'https://www.sportskeeda.com/tennis/news-arms-sensational-nick-kyrgios-gushes-carlos-alcaraz-s-singlet-spaniard-makes-fear-claim-wearing-sleeveless-outfit-us-open'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSdNjXhejwPqwkPVC3LM3OHcQY8lnL47NqYzCfGkLmi-WIh7dwWDapixCvYZos',
#                                'ht:picture_source': 'Daily Express',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:30:00 -0700',
#                                'title': 'nick kyrgios'},
#                               {'description': None,
#                                'ht:approx_traffic': '1000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTxKMzxKAO202GGRDedRoD58d4cy3qv1749MQofXudoo3QdhTyYLdUsy03WUJk',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Entertainment '
#                                                                         'Weekly',
#                                                  'ht:news_item_title': 'Marisa '
#                                                                        'Tomei '
#                                                                        'says '
#                                                                        'watching '
#                                                                        'Tom '
#                                                                        'Holland '
#                                                                        'and '
#                                                                        'Zendaya '
#                                                                        "'grow "
#                                                                        "up' "
#                                                                        'and '
#                                                                        "'fall "
#                                                                        'in \n'
#                                                                        "love' "
#                                                                        'was '
#                                                                        'her '
#                                                                        'favorite '
#                                                                        'part '
#                                                                        'of '
#                                                                        'Spider-Man',
#                                                  'ht:news_item_url': 'https://ew.com/marisa-tomei-talks-watching-tom-holland-and-zendaya-fall-in-love-8702758'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSveHyG53Kfxh-TonBGnSwFhb1WXJF8t3rQEUoLT6v0VkXn3zXNKILHyL83fus',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'People',
#                                                  'ht:news_item_title': 'Marisa '
#                                                                        'Tomei '
#                                                                        'Reflects '
#                                                                        'on '
#                                                                        'Watching '
#                                                                        'Spider-Man '
#                                                                        'Costars '
#                                                                        'Tom '
#                                                                        'Holland '
#                                                                        'and \n'
#                                                                        'Zendaya '
#                                                                        "'Fall "
#                                                                        'in '
#                                                                        "Love'",
#                                                  'ht:news_item_url': 'https://people.com/marisa-tomei-gushes-over-spider-man-costars-tom-holland-and-zendaya-8703120'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTSyMJPc4t7j8WQNSX_fg-CgX_XP4R_bS4UV4o1wrkMjBrLaULIeMy9-dkB47g',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Yahoo',
#                                                  'ht:news_item_title': 'Inside '
#                                                                        'Zendaya '
#                                                                        'and '
#                                                                        'Tom '
#                                                                        "Holland's "
#                                                                        'Marvelous '
#                                                                        'Love '
#                                                                        'Story',
#                                                  'ht:news_item_url': 'https://www.yahoo.com/entertainment/inside-zendaya-tom-hollands-marvelous-140000816.html'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTxKMzxKAO202GGRDedRoD58d4cy3qv1749MQofXudoo3QdhTyYLdUsy03WUJk',
#                                'ht:picture_source': 'Entertainment Weekly',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:30:00 -0700',
#                                'title': 'zendaya'},
#                               {'description': None,
#                                'ht:approx_traffic': '1000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTraSI6MJAe_qPS1PjdMSfxZp8uTl_jn0k8M1Q6y_1n24qRExouEmaXe_hSGF0',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Milwaukee '
#                                                                         'Journal '
#                                                                         'Sentinel',
#                                                  'ht:news_item_title': 'What '
#                                                                        'channel '
#                                                                        'is '
#                                                                        'Wisconsin '
#                                                                        'volleyball '
#                                                                        'vs. '
#                                                                        'Texas, '
#                                                                        'Stanford '
#                                                                        'on? '
#                                                                        'Time, '
#                                                                        'TV \n'
#                                                                        'schedule, '
#                                                                        'streaming '
#                                                                        'info, '
#                                                                        'radio',
#                                                  'ht:news_item_url': 'https://www.jsonline.com/story/sports/college/uw/2024/09/01/wisconsin-volleyball-vs-texas-stanford-channel-time-tv-schedule/75006392007/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRsraXGvI1UD8iJcejUA-5gnoDCLss8dSX9G2q1IsuemFCezLTIDkus1sH7uyg',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'University '
#                                                                         'of '
#                                                                         'Texas '
#                                                                         'Athletics',
#                                                  'ht:news_item_title': 'No. 1 '
#                                                                        'Volleyball '
#                                                                        'preview: '
#                                                                        'State '
#                                                                        'Farm '
#                                                                        'Women’s '
#                                                                        'Volleyball '
#                                                                        'Showcase',
#                                                  'ht:news_item_url': 'https://texaslonghorns.com/news/2024/8/30/no-1-volleyball-preview-state-farm-womens-volleyball-showcase.aspx'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRCSiDzN5wJ4ygxs-LBvq-anE7x7XXbkvyjG5KoiwHmf9wS2aklW5IScL7nTPg',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Wisconsin '
#                                                                         'Badgers',
#                                                  'ht:news_item_title': 'Setting '
#                                                                        'the '
#                                                                        'Stage: '
#                                                                        'Texas '
#                                                                        'and '
#                                                                        'Stanford '
#                                                                        'in '
#                                                                        'Cream '
#                                                                        'City',
#                                                  'ht:news_item_url': 'https://uwbadgers.com/news/2024/8/29/volleyball-setting-the-stage-texas-and-stanford-in-cream-city.aspx'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTraSI6MJAe_qPS1PjdMSfxZp8uTl_jn0k8M1Q6y_1n24qRExouEmaXe_hSGF0',
#                                'ht:picture_source': 'Milwaukee Journal '
#                                                     'Sentinel',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:30:00 -0700',
#                                'title': 'texas volleyball'},
#                               {'description': None,
#                                'ht:approx_traffic': '1000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQjZkrNz1g9kiLV99JYQjUvUJ8pwZ5H9n30ZOdKkVZy95_t8tAtnX2sNjDl2jw',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'MSNBC '
#                                                                         'News',
#                                                  'ht:news_item_title': 'Middle '
#                                                                        'class '
#                                                                        '‘wants '
#                                                                        'to see '
#                                                                        'the '
#                                                                        'contrast’ '
#                                                                        'between '
#                                                                        'Harris '
#                                                                        'and '
#                                                                        'Trump '
#                                                                        'at '
#                                                                        'first \n'
#                                                                        'debate: '
#                                                                        'Rep. '
#                                                                        'Crockett',
#                                                  'ht:news_item_url': 'https://www.msnbc.com/weekends-with-alex-witt/watch/middle-class-wants-to-see-the-contrast-between-harris-and-trump-at-first-debate-rep-crockett-218382917651'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSVbNpWwxyLpmUSiXeODQp17FLETxzF6OjrvPSPa6WENc_PRRCI72iKEj37wHc',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'NBC '
#                                                                         'News',
#                                                  'ht:news_item_title': 'Trump '
#                                                                        'suggests '
#                                                                        'he may '
#                                                                        'back '
#                                                                        'out of '
#                                                                        'a '
#                                                                        'Sept. '
#                                                                        '10 ABC '
#                                                                        'debate',
#                                                  'ht:news_item_url': 'https://www.nbcnews.com/politics/2024-election/trump-suggests-may-back-sept-10-abc-debate-rcna168198'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSkjjp09E68YVn_GJuS18jBhQGsZQ52YCw42scN2rVIoqKgxPc9azC5ny8qL5U',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'The '
#                                                                         'New '
#                                                                         'York '
#                                                                         'Times',
#                                                  'ht:news_item_title': 'Opinion '
#                                                                        '| '
#                                                                        'Trump '
#                                                                        'Should '
#                                                                        'Be '
#                                                                        'Scared '
#                                                                        '— Very '
#                                                                        'Scared '
#                                                                        '— of '
#                                                                        'Debating '
#                                                                        'Kamala '
#                                                                        'Harris',
#                                                  'ht:news_item_url': 'https://www.nytimes.com/2024/08/29/opinion/trump-kamala-harris-debate.html'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQjZkrNz1g9kiLV99JYQjUvUJ8pwZ5H9n30ZOdKkVZy95_t8tAtnX2sNjDl2jw',
#                                'ht:picture_source': 'MSNBC News',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:20:00 -0700',
#                                'title': 'presidential debates'},
#                               {'description': None,
#                                'ht:approx_traffic': '500+',
#                                'ht:news_item': {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRqymhd84naJR6v4l-Qrwn_retZCgJsUYpyBfmiqTHer_ZgZj3PJet9uGwEag8',
#                                                 'ht:news_item_snippet': None,
#                                                 'ht:news_item_source': 'OneFootball',
#                                                 'ht:news_item_title': 'Pre-match '
#                                                                       'programme '
#                                                                       'for '
#                                                                       'first '
#                                                                       'home '
#                                                                       'game '
#                                                                       'against '
#                                                                       'Freiburg',
#                                                 'ht:news_item_url': 'https://onefootball.com/de/news/pre-match-programme-for-first-home-game-against-freiburg-39968940'},
#                                'ht:picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRqymhd84naJR6v4l-Qrwn_retZCgJsUYpyBfmiqTHer_ZgZj3PJet9uGwEag8',
#                                'ht:picture_source': 'OneFootball',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:20:00 -0700',
#                                'title': 'bayern'},
#                               {'description': None,
#                                'ht:approx_traffic': '500+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRSOZ-YGFFaLYwE41nQJANrD_u7v4UYrxstDP-2tyDAYk5ZPFFSHeuWoovhSww',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'areacucuta.com',
#                                                  'ht:news_item_title': 'Los '
#                                                                        'Cabos: '
#                                                                        'El '
#                                                                        'Paraíso '
#                                                                        'Que '
#                                                                        'Eligen '
#                                                                        'Las '
#                                                                        'Celebridades '
#                                                                        'Para '
#                                                                        'Pasar '
#                                                                        'Sus '
#                                                                        'Vacaciones \n'
#                                                                        'En '
#                                                                        'Latinoamérica',
#                                                  'ht:news_item_url': 'https://www.areacucuta.com/los-cabos-el-paraiso-que-eligen-las-celebridades-para-pasar-sus-vacaciones-en-latinoamerica/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSnKtfAKvAXoseaxb4Y-JB430o-n3A2_Dv8uD0kvDzByUzI3mXr6YQBq3N_q8U',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'www.meganoticias.mx',
#                                                  'ht:news_item_title': '"Gandhi", '
#                                                                        'primera '
#                                                                        'librería '
#                                                                        'y '
#                                                                        'papelería '
#                                                                        'en Los '
#                                                                        'Cabos',
#                                                  'ht:news_item_url': 'https://www.meganoticias.mx/los-cabos/noticia/gandhi-primera-libreria-y-papeleria-en-los-cabos/546944'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRgJ7bPh1LAab1_fSPedsp7zH_hP3bqNpDgSc5n5mmVWoceqYF12z4QD6kdOxA',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'BCS '
#                                                                         'Noticias',
#                                                  'ht:news_item_title': 'Milagros '
#                                                                        'de 13 '
#                                                                        'años '
#                                                                        'está '
#                                                                        'desaparecida; '
#                                                                        'activan '
#                                                                        'Protocolo '
#                                                                        'Alba '
#                                                                        'en Los '
#                                                                        'Cabos \n'
#                                                                        'para '
#                                                                        'encontrarla',
#                                                  'ht:news_item_url': 'https://www.bcsnoticias.mx/milagros-de-13-anos-esta-desaparecida-activan-protocolo-alba-en-los-cabos-para-encontrarla-1/'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRSOZ-YGFFaLYwE41nQJANrD_u7v4UYrxstDP-2tyDAYk5ZPFFSHeuWoovhSww',
#                                'ht:picture_source': 'areacucuta.com',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:20:00 -0700',
#                                'title': 'cabo san lucas'},
#                               {'description': None,
#                                'ht:approx_traffic': '10000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSGTAA3GtZTol0LkKdG2jqkHuVBSuCIcUnObMEJhadgkdB4W5oM4joo1sUVmbc',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'US '
#                                                                         'Open',
#                                                  'ht:news_item_title': 'Andrey '
#                                                                        'Rublev '
#                                                                        'and '
#                                                                        'Grigor '
#                                                                        "Dimitrov's "
#                                                                        'bromance '
#                                                                        'returns '
#                                                                        'to the '
#                                                                        '2024 '
#                                                                        'US '
#                                                                        'Open',
#                                                  'ht:news_item_url': 'https://www.usopen.org/en_US/news/articles/2024-08-31/andrey_rublev_and_grigor_dimitrovs_bromance_returns_to_the_2024_us_open.html'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQFQN-JB2Z9N1LcPICgY_ie549u_bCiQUsr1R7VeP604UjhCib-lReXr_19JVU',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'BBC',
#                                                  'ht:news_item_title': 'US '
#                                                                        'Open '
#                                                                        'LIVE: '
#                                                                        'Andrey '
#                                                                        'Rublev '
#                                                                        'v '
#                                                                        'Grigor '
#                                                                        'Dimitrov, '
#                                                                        'Coco '
#                                                                        'Gauff '
#                                                                        'v Emma '
#                                                                        'Navarro '
#                                                                        '- \n'
#                                                                        'live '
#                                                                        'text '
#                                                                        'and '
#                                                                        'radio '
#                                                                        'commentary',
#                                                  'ht:news_item_url': 'https://www.bbc.com/sport/tennis/live/czxlexqn5qgt'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQkhqfQQb63hlUoy4GeL-dpWQaUaWz9rTnzUThnAdvP-1j_nY0NtRbrMMlFQBY',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'VSiN',
#                                                  'ht:news_item_title': 'US '
#                                                                        'Open '
#                                                                        'Predictions: '
#                                                                        'Tennis '
#                                                                        'best '
#                                                                        'bets '
#                                                                        'and '
#                                                                        'picks '
#                                                                        'for '
#                                                                        'Sunday, '
#                                                                        'September '
#                                                                        '1st',
#                                                  'ht:news_item_url': 'https://vsin.com/tennis/us-open-predictions-tennis-best-bets-and-picks-for-sunday-september-1st/'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSGTAA3GtZTol0LkKdG2jqkHuVBSuCIcUnObMEJhadgkdB4W5oM4joo1sUVmbc',
#                                'ht:picture_source': 'US Open',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:10:00 -0700',
#                                'title': 'rublev'},
#                               {'description': None,
#                                'ht:approx_traffic': '200000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTt8lACsuLJI77dSGHAmAnJsumR01qbVdbNRfcKkpCXZ5qJsILrmv3uOvvZGU4',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'ESPN',
#                                                  'ht:news_item_title': "'It "
#                                                                        "wasn't "
#                                                                        "pretty,' "
#                                                                        'but '
#                                                                        'No. 7 '
#                                                                        'Irish '
#                                                                        'proud '
#                                                                        'of win',
#                                                  'ht:news_item_url': 'https://www.espn.com/college-football/story/_/id/41078759/no-7-notre-dame-spoils-debut-texas-coach-mike-elko'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSnma38s7ZPc-CnI3Ixt_g6ew9qU4MVKXfUhn_umL-pHbs15Bb9ifznZu6Wfgw',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'USA '
#                                                                         'Today',
#                                                  'ht:news_item_title': 'Are '
#                                                                        'college '
#                                                                        'football '
#                                                                        'games '
#                                                                        'on '
#                                                                        'today? '
#                                                                        'Time, '
#                                                                        'TV, '
#                                                                        'streaming '
#                                                                        'for '
#                                                                        'Week 1 '
#                                                                        'Sunday \n'
#                                                                        'schedule',
#                                                  'ht:news_item_url': 'https://www.usatoday.com/story/sports/ncaaf/2024/09/01/college-football-games-today-schedule-week-1-sunday/75041025007/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSp5SxHWb7fGn3nfmaP62G_tYIkvLgJGBCfs14ghySO3aMeWagqDo9UuFzcZCk',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Austin '
#                                                                         'American-Statesman',
#                                                  'ht:news_item_title': 'Texas '
#                                                                        'A&M '
#                                                                        'takeaways: '
#                                                                        'Conner '
#                                                                        'Weigman '
#                                                                        'hurt '
#                                                                        'the '
#                                                                        'Aggies, '
#                                                                        'his '
#                                                                        'NFL '
#                                                                        'draft '
#                                                                        'stock \n'
#                                                                        'vs. '
#                                                                        'Notre '
#                                                                        'Dame',
#                                                  'ht:news_item_url': 'https://www.statesman.com/story/sports/college/aggies/2024/08/31/texas-am-football-aggies-notre-dame-fighting-irish/75036406007/'}],
#                                'ht:picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTt8lACsuLJI77dSGHAmAnJsumR01qbVdbNRfcKkpCXZ5qJsILrmv3uOvvZGU4',
#                                'ht:picture_source': 'ESPN',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:10:00 -0700',
#                                'title': 'lou holtz'},
#                               {'description': None,
#                                'ht:approx_traffic': '2000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQJr2CfYqIct0GDjdLhZttRclPxr8P3EAkZm1OAtGPruGFqBrUrLWeXJOp22ZY',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'New '
#                                                                         'York '
#                                                                         'Post',
#                                                  'ht:news_item_title': 'Man '
#                                                                        'kicked '
#                                                                        'off '
#                                                                        'Delta '
#                                                                        'flight '
#                                                                        'for '
#                                                                        'wearing '
#                                                                        'Donald '
#                                                                        'Trump '
#                                                                        'tee '
#                                                                        'with '
#                                                                        '‘hawk '
#                                                                        'tuah’ \n'
#                                                                        'girl '
#                                                                        'meme '
#                                                                        'reference',
#                                                  'ht:news_item_url': 'https://nypost.com/2024/08/31/us-news/man-kicked-off-delta-flight-for-wearing-obscene-donald-trump-tee-with-viral-meme-reference/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTT-uDEWn7DpXcpGlFM-rLwJH7-CdFD1YTnAFRWef3ljjvNQzkxSj78vutSOO8',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Hindustan '
#                                                                         'Times',
#                                                  'ht:news_item_title': 'Passenger '
#                                                                        'removed '
#                                                                        'from '
#                                                                        'Delta '
#                                                                        'flight '
#                                                                        'for '
#                                                                        'Trump '
#                                                                        'and '
#                                                                        'Hawk '
#                                                                        'Tuah '
#                                                                        'girl '
#                                                                        'meme \n'
#                                                                        'T-Shirt: '
#                                                                        '‘I’m '
#                                                                        'getting '
#                                                                        "kicked…'",
#                                                  'ht:news_item_url': 'https://www.hindustantimes.com/world-news/us-news/passenger-removed-from-delta-flight-for-trump-and-hawk-tuah-girl-meme-t-shirt-i-m-getting-kicked-101725161921069.html'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSzZ4AV30w0n8lMBWZBrdNSbDXfIJ2R9KjRqUWW4nHXPtJou-guZoWOZxEr30c',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Times '
#                                                                         'of '
#                                                                         'India',
#                                                  'ht:news_item_title': "'Hawk "
#                                                                        'tuah '
#                                                                        'spit '
#                                                                        'on '
#                                                                        'that '
#                                                                        "thang': "
#                                                                        'Man '
#                                                                        'kicked '
#                                                                        'out of '
#                                                                        'Delta '
#                                                                        'flight '
#                                                                        'over '
#                                                                        'Trump \n'
#                                                                        't-shirt',
#                                                  'ht:news_item_url': 'https://timesofindia.indiatimes.com/world/us/hawk-tuah-spit-on-that-thang-man-kicked-out-of-delta-flight-over-trump-t-shirt/articleshow/112962559.cms'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQJr2CfYqIct0GDjdLhZttRclPxr8P3EAkZm1OAtGPruGFqBrUrLWeXJOp22ZY',
#                                'ht:picture_source': 'New York Post',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sun, 1 Sep 2024 09:10:00 -0700',
#                                'title': 'delta airlines news'}],
#                      'link': 'https://trends.google.com/trending/rss?geo=US',
#                      'title': 'Daily Search Trends'}}}

# %%
# create google trends dataframe

google_trends_dict = {"trend_kws":[], "traffic":[], "pubDate":[], "url":[], "title":[]}

for trend in trends_dict['rss']['channel']['item']:
    google_trends_dict['trend_kws'].append(trend['title'])
    google_trends_dict['traffic'].append(trend['ht:approx_traffic'])
    google_trends_dict['pubDate'].append(trend['pubDate'])
    if isinstance(trend['ht:news_item'], list):
        google_trends_dict['url'].append([news_item['ht:news_item_url'] for news_item in trend['ht:news_item']])
        google_trends_dict['title'].append([news_item['ht:news_item_title'] for news_item in trend['ht:news_item']])
    else:
        google_trends_dict['url'].append([trend['ht:news_item']['ht:news_item_url']])
        google_trends_dict['title'].append([trend['ht:news_item']['ht:news_item_title']])

google_trends_df = pd.DataFrame(google_trends_dict)

# %%
# clean data

google_trends_df["title"] = google_trends_df["title"].map(lambda links: [link.replace("&#39;", "'") for link in links])

# %%
google_trends_df.head()
# Out:
#               trend_kws traffic                         pubDate  \
# 0          fantasy pros    500+  Sun, 1 Sep 2024 09:40:00 -0700
# 1          nick kyrgios   1000+  Sun, 1 Sep 2024 09:30:00 -0700
# 2               zendaya   1000+  Sun, 1 Sep 2024 09:30:00 -0700
# 3      texas volleyball   1000+  Sun, 1 Sep 2024 09:30:00 -0700
# 4  presidential debates   1000+  Sun, 1 Sep 2024 09:20:00 -0700
#
#                                                  url  \
# 0  [https://www.nbcsports.com/fantasy/football/ne...
# 1  [https://www.express.co.uk/sport/tennis/194233...
# 2  [https://ew.com/marisa-tomei-talks-watching-to...
# 3  [https://www.jsonline.com/story/sports/college...
# 4  [https://www.msnbc.com/weekends-with-alex-witt...
#
#                                                title
# 0  [Fantasy Football 2024: Rotoworld staff most d...
# 1  [Carlos Alcaraz and Nick Kyrgios' DMs to each ...
# 2  [Marisa Tomei says watching Tom Holland and Ze...
# 3  [What channel is Wisconsin volleyball vs. Texa...
# 4  [Middle class ‘wants to see the contrast’ betw...

# %%
# define the list of domains to skip

domains_skip_list = ["msn.com", "washingtonpost.com"]

# %%
# remove urls that contain domains in domains_skip_list

for i in range(google_trends_df.shape[0]):
    for j, url in enumerate(google_trends_df.loc[i,"url"]):
        if any(domain in url for domain in domains_skip_list):
            _ = google_trends_df.loc[i,"url"].pop(j)
            _ = google_trends_df.loc[i,"title"].pop(j)

# %%
google_trends_df.head(20)
# Out:
#               trend_kws  traffic                         pubDate  \
# 0          fantasy pros     500+  Sun, 1 Sep 2024 09:40:00 -0700
# 1          nick kyrgios    1000+  Sun, 1 Sep 2024 09:30:00 -0700
# 2               zendaya    1000+  Sun, 1 Sep 2024 09:30:00 -0700
# 3      texas volleyball    1000+  Sun, 1 Sep 2024 09:30:00 -0700
# 4  presidential debates    1000+  Sun, 1 Sep 2024 09:20:00 -0700
# 5                bayern     500+  Sun, 1 Sep 2024 09:20:00 -0700
# 6        cabo san lucas     500+  Sun, 1 Sep 2024 09:20:00 -0700
# 7                rublev   10000+  Sun, 1 Sep 2024 09:10:00 -0700
# 8             lou holtz  200000+  Sun, 1 Sep 2024 09:10:00 -0700
# 9   delta airlines news    2000+  Sun, 1 Sep 2024 09:10:00 -0700
#
#                                                  url  \
# 0  [https://www.nbcsports.com/fantasy/football/ne...
# 1  [https://www.express.co.uk/sport/tennis/194233...
# 2  [https://ew.com/marisa-tomei-talks-watching-to...
# 3  [https://www.jsonline.com/story/sports/college...
# 4  [https://www.msnbc.com/weekends-with-alex-witt...
# 5  [https://onefootball.com/de/news/pre-match-pro...
# 6  [https://www.areacucuta.com/los-cabos-el-parai...
# 7  [https://www.usopen.org/en_US/news/articles/20...
# 8  [https://www.espn.com/college-football/story/_...
# 9  [https://nypost.com/2024/08/31/us-news/man-kic...
#
#                                                title
# 0  [Fantasy Football 2024: Rotoworld staff most d...
# 1  [Carlos Alcaraz and Nick Kyrgios' DMs to each ...
# 2  [Marisa Tomei says watching Tom Holland and Ze...
# 3  [What channel is Wisconsin volleyball vs. Texa...
# 4  [Middle class ‘wants to see the contrast’ betw...
# 5  [Pre-match programme for first home game again...
# 6  [Los Cabos: El Paraíso Que Eligen Las Celebrid...
# 7  [Andrey Rublev and Grigor Dimitrov's bromance ...
# 8  ['It wasn't pretty,' but No. 7 Irish proud of ...
# 9  [Man kicked off Delta flight for wearing Donal...

# %%
# get trends related news articles from ddg web search

trends_news = []
for trend_kw in tqdm(google_trends_df.trend_kws.to_list()):
    results = DDGS().news(keywords=trend_kw, region="wt-wt", safesearch="moderate", max_results=15)
    filtered_results = [res for res in results if not any(domain in res['url'] for domain in domains_skip_list)]
    filtered_results = list(map(lambda d: {'trend_kws':trend_kw, **d}, filtered_results[:5]))
    trends_news.extend(filtered_results)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
# create ddg news articles dataframe

trends_ddg_news_df = pd.DataFrame(trends_news)
trends_ddg_news_df.head(10)
# Out:
#       trend_kws                       date  \
# 0  nick kyrgios  2024-09-01T00:37:00+00:00
# 1  nick kyrgios  2024-08-31T08:00:00+00:00
# 2  nick kyrgios  2024-08-30T14:14:00+00:00
# 3  nick kyrgios  2024-08-29T22:06:00+00:00
# 4  nick kyrgios  2024-08-30T12:45:00+00:00
# 5       zendaya  2024-09-01T16:00:00+00:00
# 6       zendaya  2024-08-29T23:06:00+00:00
# 7       zendaya  2024-08-28T16:02:00+00:00
# 8       zendaya  2024-08-30T07:39:00+00:00
# 9       zendaya  2024-08-31T19:21:00+00:00
#
#                                                title  \
# 0  Alexei Popyrin focused on next step at US Open...
# 1  Nick Kyrgios rips Jannik Sinner with new bruta...
# 2  Nick Kyrgios reveals DMs and close bond with C...
# 3  Jannik Sinner responds to whether he will allo...
# 4  Carlos Alcaraz and Nick Kyrgios' DMs to each o...
# 5  Jenna Ortega Once Auditioned for a Major Film ...
# 6  Marisa Tomei Recalls Watching Tom Holland & Ze...
# 7  Marisa Tomei says watching Tom Holland and Zen...
# 8  Marisa Tomei reflects on Tom Holland and Zenda...
# 9  Marisa Tomei recounts Tom Holland-Zendaya's bl...
#
#                                                 body  \
# 0  Nick Kyrgios believes Alexei Popyrin has what ...
# 1  The Australian has once again harshly attacked...
# 2  Nick Kyrgios has revealed the extent of his re...
# 3  Jannik Sinner admitted "It's going to be diffe...
# 4  Carlos Alcaraz shocked the world as he was kno...
# 5  Several years back, it seems Jenna Ortega and ...
# 6  The Academy Award winner had fond memories of ...
# 7  Marisa Tomei's spidey senses told her the roma...
# 8  Tomei recalled how she watched Holland and Zen...
# 9  "I think some of the favorite things were real...
#
#                                                  url  \
# 0  https://www.abc.net.au/news/2024-09-01/alexei-...
# 1  https://www.tennisworldusa.org/tennis/news/Ten...
# 2  https://www.mirror.co.uk/sport/tennis/nick-kyr...
# 3  https://www.express.co.uk/sport/tennis/1942106...
# 4  https://www.express.co.uk/sport/tennis/1942333...
# 5  https://www.yahoo.com/entertainment/jenna-orte...
# 6  https://deadline.com/2024/08/marisa-tomei-watc...
# 7  https://nypost.com/2024/08/28/entertainment/ma...
# 8  https://timesofindia.indiatimes.com/entertainm...
# 9  https://www.hindustantimes.com/htcity/cinema/m...
#
#                                                image  \
# 0  https://live-production.wcms.abc-cdn.net.au/b6...
# 1  https://www.tennisworldusa.org/world/media/ima...
# 2  https://i2-prod.mirror.co.uk/sport/article3356...
# 3  https://cdn.images.express.co.uk/img/dynamic/7...
# 4  https://cdn.images.express.co.uk/img/dynamic/7...
# 5
# 6  https://deadline.com/wp-content/uploads/2024/0...
# 7  https://nypost.com/wp-content/uploads/sites/2/...
# 8  https://static.toiimg.com/thumb/msid-112918747...
# 9  https://www.hindustantimes.com/ht-img/img/2024...
#
#                                 source
# 0  Australian Broadcasting Corporation
# 1                         Tennis World
# 2                           The Mirror
# 3                        Daily Express
# 4                        Daily Express
# 5                                Yahoo
# 6                         Deadline.com
# 7                        New York Post
# 8                           Indiatimes
# 9                      Hindustan Times

# %%
# update google trends dataframe with ddg news articles urls and titles

for i, trend in enumerate(google_trends_df.trend_kws):
    url_list = trends_ddg_news_df[trends_ddg_news_df["trend_kws"]==trend]['url'].to_list()
    title_list = trends_ddg_news_df[trends_ddg_news_df["trend_kws"]==trend]['title'].to_list()
    google_trends_df.loc[i, "url"].extend(url_list)
    google_trends_df.loc[i, "title"].extend(title_list)

# %%
google_trends_df.title[0]
# Out:
# ['Fantasy Football 2024: Rotoworld staff most drafted players',
#  '2024 Fantasy football draft strategy: Tiers, cheat sheets, best breakout \nplayers, deep sleepers by NFL expert',
#  "Don't be surprised if ... : Fantasy predictions for 2024"]

# %%
google_trends_df.url[0]
# Out:
# ['https://www.nbcsports.com/fantasy/football/news/fantasy-football-2024-rotoworld-staff-most-drafted-players',
#  'https://www.cbssports.com/fantasy/football/news/2024-fantasy-football-draft-strategy-tiers-cheat-sheets-best-breakout-players-deep-sleepers-by-nfl-expert/',
#  'https://www.espn.com/fantasy/football/story/_/id/41032720/2024-fantasy-football-rankings-draft-picks-predictions-surprises']

# %% [markdown]
# ## Performing RAG (Retrieval-Augmented Generation)

# %%
# import libraries for rag with langchain

from langchain_community.document_loaders import SeleniumURLLoader, UnstructuredURLLoader, WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel
from langchain_core.utils.function_calling import convert_to_openai_tool
from langchain_core.runnables import RunnableLambda

# %%
# define embedding model
embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# define llm
llm = ChatOllama(
    model="llama3.1",
    temperature=0.2,
    keep_alive="2m",
    repeat_penalty=1.03,
    # other params...
)


# define prompt template
prompt_template = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            You are a helpful assistant that specializes in article summarization.
            Your task is to summarize a given text article and generate a title for it.
            If the provided article doesn't contain coherent and meaningful content, just return an empty response.
            """,
        ),
        ("human", "Article: {article}"),
    ]
)


# define output schema for llm
class SummmaryWithTitle(BaseModel):
    '''Article summary and title.'''
    title: str
    summary: str

dict_schema = convert_to_openai_tool(SummmaryWithTitle)
structured_output_llm = llm.with_structured_output(dict_schema)

# %%
# define helper functions

def url_loader(url_list:list[str], loader_type:str="Unstructured"):
    if loader_type == "Unstructured":
        unstruct_loader = UnstructuredURLLoader(url_list)
        data = unstruct_loader.load()
    elif loader_type == "Selenium":
        sele_loader = SeleniumURLLoader(url_list)
        driver = sele_loader._get_driver()
        try:
            data = sele_loader.load()
        finally:
            driver.close()
            driver.quit()
    elif loader_type == "Base":
        header_template = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        base_loader = WebBaseLoader(url_list, header_template=header_template)
        data = base_loader.load()
    else:
        raise ValueError(f"Loader type {loader_type} not supported.")
    return data


def rec_splitter(url_doc_list:list):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=400,
                                                   chunk_overlap=50,
                                                   add_start_index=True)
    all_splits = text_splitter.split_documents(url_doc_list)
    return all_splits


def reteived_docs_parser(ret_doc_list:list):
    ret_article = "\n".join([doc.page_content for doc in ret_doc_list])
    ret_article = ret_article.replace('\n\n', '. ')
    ret_article_sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<![A-Z][a-z][A-Z]\.)(?<=\.|\?|!|\n)\s*', ret_article)
    ret_article_meaningful_sentences = [s for s in ret_article_sentences if len(s.split()) > 5]
    meaningful_ret_article = '\n'.join(ret_article_meaningful_sentences)
    return meaningful_ret_article

reteived_docs_parser_runnable = RunnableLambda(reteived_docs_parser)

# %%
# define functions to run the rag pipeline

def run_rag_chain_once(trend, google_df, ddg_df, embeddings_model, reteived_docs_parser_runnable, prompt_template, structured_output_llm):
    print("# Starting RAG pipeline")
    start = time.time()

    print("## Scraping Articles")
    df_trend = google_df[google_df["trend_kws"]==trend]
    url_list = df_trend['url'].iloc[0]
    print(url_list)
    try:
        url_docs = url_loader(url_list, "Base")
        if len(" ".join([doc.page_content for doc in url_docs])) < 5000:
            print("Using UnstructuredLoader")
            url_docs = url_loader(url_list, "Unstructured")
    except Exception as e:
        print("Exception BaseURLLoader:", e)
        print("Using UnstructuredLoader")
        url_docs = url_loader(url_list, "Unstructured")

        
    for doc in url_docs:
        if (doc.page_content == "") & (doc.metadata["source"] in ddg_df.url.to_list()):
            article_body_index = ddg_df['url'].to_list().index(doc.metadata["source"])
            doc.page_content += ddg_df['body'][article_body_index]
    scraping_checkpoint = time.time()
    scraping_dur = scraping_checkpoint - start

    print("## Creating FAISS vectorstore")
    splits_docs = rec_splitter(url_docs)
    faiss_db = FAISS.from_documents(splits_docs, embeddings_model)
    faiss_retriever = faiss_db.as_retriever(search_type="similarity",
                                search_kwargs={'k': 5})
    faiss_checkpoint = time.time()
    faiss_dur = faiss_checkpoint - scraping_checkpoint

    print("## Performing RAG")
    ret_query = '\n'.join(df_trend['title'].iloc[0])
    rag_chain = (faiss_retriever
                    | { "article": reteived_docs_parser_runnable }
                    | prompt_template
                    | structured_output_llm)
    rag_results = rag_chain.invoke(ret_query)
    end = time.time()
    chain_dur = end - faiss_checkpoint
    print(f"Scrape: {scraping_dur}, Faiss: {faiss_dur}, Chain: {chain_dur}")
    return rag_results


def run_rag_chain_loop(google_df, ddg_df, embeddings_model, reteived_docs_parser_runnable, prompt_template, structured_output_llm):

    results={"Trend_kws":[], "Title":[], "Summary":[]}
    #trend_kws = ddg_news_df.trend_kws.value_counts().index.to_list()
    trend_kws = google_df.trend_kws.to_list()

    for i, trend_kw in tqdm(enumerate(trend_kws), total=len(trend_kws)):
        print(f"Trend number {i+1} of {len(trend_kws)}")
        if google_df[google_df["trend_kws"]==trend_kw]['url'].iloc[0]:
            rag_results = run_rag_chain_once(trend_kw, google_df, ddg_df, embeddings_model, reteived_docs_parser_runnable, prompt_template, structured_output_llm)
        else:
            rag_results = {'title':trend_kw, 'summary':'No enough information yet!'}
        print(f"""### Trend Keyword: {trend_kw}\n ### Title: {rag_results['title']}\n ### Summary: {rag_results['summary']}\n\n""")
        results['Trend_kws'].append(trend_kw)
        results['Title'].append(rag_results['title'])
        results['Summary'].append(rag_results['summary'])
        
    return results

# %%
# test the rag pipeline

results = run_rag_chain_loop(google_trends_df, trends_ddg_news_df, embeddings_model, reteived_docs_parser_runnable, prompt_template, structured_output_llm)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Trend number 1 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://www.nbcsports.com/fantasy/football/news/fantasy-football-2024-rotoworld-staff-most-drafted-players', 'https://www.cbssports.com/fantasy/football/news/2024-fantasy-football-draft-strategy-tiers-cheat-sheets-best-breakout-players-deep-sleepers-by-nfl-expert/', 'https://www.espn.com/fantasy/football/story/_/id/41032720/2024-fantasy-football-rankings-draft-picks-predictions-surprises']
# ## Creating FAISS vectorstore
# ## Performing RAG
# Scrape: 6.709356307983398, Faiss: 0.35988926887512207, Chain: 18.945935249328613
# ### Trend Keyword: fantasy pros
#  ### Title: 2024 Fantasy Football Draft Strategy and Rankings
#  ### Summary: The article discusses the 2024 fantasy football draft strategy, including tiers, cheat sheets, best breakout players, and deep sleepers. It also provides fantasy football rankings for the 2024 season, advice, and picks. Additionally, it highlights bust risks at current ADP and provides offensive depth charts for the 2024 season.
#
#
# Trend number 2 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://www.express.co.uk/sport/tennis/1942333/Carlos-Alcaraz-Nick-Kyrgios-Tennis-US-Open', 'https://www.si.com/onsi/serve/style/nick-kyrgios-hilariously-roasts-carlos-alcaraz-us-open-outfit', 'https://www.sportskeeda.com/tennis/news-arms-sensational-nick-kyrgios-gushes-carlos-alcaraz-s-singlet-spaniard-makes-fear-claim-wearing-sleeveless-outfit-us-open', 'https://www.abc.net.au/news/2024-09-01/alexei-popyrin-focused-on-next-step-at-us-open-nick-kyrgios/104296268', 'https://www.tennisworldusa.org/tennis/news/Tennis_Stories/147847/nick-kyrgios-rips-jannik-sinner-with-new-brutal-accusations/', 'https://www.mirror.co.uk/sport/tennis/nick-kyrgios-carlos-alcaraz-usopen-33569266', 'https://www.express.co.uk/sport/tennis/1942106/jannik-sinner-responds-Nick-Kyrgios-US-Open', 'https://www.express.co.uk/sport/tennis/1942333/Carlos-Alcaraz-Nick-Kyrgios-Tennis-US-Open']
# ## Creating FAISS vectorstore
# ## Performing RAG
# Scrape: 10.366424322128296, Faiss: 0.4662313461303711, Chain: 14.195277452468872
# ### Trend Keyword: nick kyrgios
#  ### Title: Nick Kyrgios reveals DMs and close bond with Carlos Alcaraz amid US Open shock exit
#  ### Summary: Nick Kyrgios has revealed the extent of his relationship with Carlos Alcaraz after the Spaniard's shock US Open exit in the second round at the hands of Botic van de Zandschulp. Their private DMs have emerged, showing a close bond between the two tennis players.
#
#
# Trend number 3 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://ew.com/marisa-tomei-talks-watching-tom-holland-and-zendaya-fall-in-love-8702758', 'https://people.com/marisa-tomei-gushes-over-spider-man-costars-tom-holland-and-zendaya-8703120', 'https://www.yahoo.com/entertainment/inside-zendaya-tom-hollands-marvelous-140000816.html', 'https://www.yahoo.com/entertainment/jenna-ortega-once-auditioned-major-160000080.html', 'https://deadline.com/2024/08/marisa-tomei-watching-tom-holland-zendaya-fall-in-love-spider-man-films-1236073427/', 'https://nypost.com/2024/08/28/entertainment/marisa-tomei-gushes-over-watching-tom-holland-zendaya-fall-in-love-on-spider-man-set/', 'https://timesofindia.indiatimes.com/entertainment/english/hollywood/news/marisa-tomei-reflects-on-tom-holland-and-zendayas-real-life-romance-during-spider-man-filming/articleshow/112917066.cms', 'https://www.hindustantimes.com/htcity/cinema/marisa-tomei-recounts-tom-holland-zendayas-blossoming-romance-while-filming-spiderman-101725091319735.html']
# ## Creating FAISS vectorstore
# ## Performing RAG
# Scrape: 14.696786403656006, Faiss: 0.35480237007141113, Chain: 10.10594129562378
# ### Trend Keyword: zendaya
#  ### Title: Marisa Tomei recounts Tom Holland-Zendaya's blossoming romance while filming Spider-Man
#  ### Summary: Marisa Tomei reflects on Tom Holland and Zendaya’s real-life romance during 'Spider-Man' filming. She says watching them fall in love was her favorite part of the experience.
#
#
# Trend number 4 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://www.jsonline.com/story/sports/college/uw/2024/09/01/wisconsin-volleyball-vs-texas-stanford-channel-time-tv-schedule/75006392007/', 'https://texaslonghorns.com/news/2024/8/30/no-1-volleyball-preview-state-farm-womens-volleyball-showcase.aspx', 'https://uwbadgers.com/news/2024/8/29/volleyball-setting-the-stage-texas-and-stanford-in-cream-city.aspx', 'https://www.si.com/college/texas/news/former-texas-volleyball-player-pilar-victoria-passes-away-at-age-28-01j6hwbb7mjs', 'https://sixerswire.usatoday.com/story/sports/college/longhorns/2024/08/31/the-date-in-texas-history-record-winning-streak-begins-in-volleyball/74986460007/', 'https://omaha.com/sports/huskers/volleyball/photos-nebraska-volleyball-hosts-texas-a-m-corpus-christi/collection_6236b4be-6593-11ef-b948-d34cbcc8d988.html', 'https://omaha.com/sports/article_7fd1b857-d12e-5f27-9a65-dacc6b660910.html', 'https://www.1011now.com/2024/08/31/nebraska-volleyball-team-defeats-texas-am-corpus-christi/']
# ## Creating FAISS vectorstore
# ## Performing RAG
# Scrape: 34.96058988571167, Faiss: 0.5299451351165771, Chain: 6.959720134735107
# ### Trend Keyword: texas volleyball
#  ### Title: What channel is Wisconsin volleyball vs.
#  ### Summary: The No. 3 Wisconsin volleyball team will be one-of-four teams competing in the State Farm Women
#
#
# Trend number 5 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://www.msnbc.com/weekends-with-alex-witt/watch/middle-class-wants-to-see-the-contrast-between-harris-and-trump-at-first-debate-rep-crockett-218382917651', 'https://www.nbcnews.com/politics/2024-election/trump-suggests-may-back-sept-10-abc-debate-rcna168198', 'https://www.nytimes.com/2024/08/29/opinion/trump-kamala-harris-debate.html', 'https://www.yahoo.com/news/jasmine-crockett-says-kamala-harris-010054714.html', 'https://www.grandforksherald.com/opinion/editorials/american-opinion-american-public-needs-to-hear-harris-and-trump-debate', 'https://www.yahoo.com/news/maddow-blog-why-plans-next-135257883.html', 'https://chicago.suntimes.com/democracy/2024/08/31/debate-kamala-harris-donald-trump-presidential-election-mics-viewers-democracy-editorial', 'https://www.nbcnewyork.com/decision-2024/when-is-next-presidential-debate-2024-kamala-harris-donald-trump/5732399/?os&ref=app']
# ## Creating FAISS vectorstore
# ## Performing RAG
# Scrape: 20.85404944419861, Faiss: 0.3221559524536133, Chain: 11.85460615158081
# ### Trend Keyword: presidential debates
#  ### Title: When’s the Kamala Harris, Donald Trump 2024 presidential debate?
#  ### Summary: Presidential debates are a tradition worth keeping, so bring on Harris-Trump. They are, after all, vying for the most important job in the nation, if not the world. Showing fitness for the office is imperative.
#
#
# Trend number 6 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://onefootball.com/de/news/pre-match-programme-for-first-home-game-against-freiburg-39968940', 'https://www.espn.com/video/clip/_/id/41083941', 'https://www.cnet.com/tech/services-and-software/bundesliga-soccer-livestream-how-to-watch-bayern-munich-vs-freiburg-from-anywhere/', 'https://www.thescore.com/deu_fed/news/3065561', 'https://sports.yahoo.com/monza-still-eyeing-ex-inter-141400034.html', 'https://sports.yahoo.com/kingsley-coman-set-stay-bayern-134100378.html']
# ## Creating FAISS vectorstore
# ## Performing RAG
# Scrape: 14.17962908744812, Faiss: 0.33159852027893066, Chain: 12.608720779418945
# ### Trend Keyword: bayern
#  ### Title: Bundesliga Soccer Livestream: How to Watch Bayern Munich vs.
#  ### Summary: The article discusses how to watch the Bundesliga soccer match between Bayern Munich and Freiburg. It mentions that Vincent Kompany will be taking charge of his first home game at the Allianz Arena and provides information on how to access the livestream on ESPN Plus.
#
#
# Trend number 7 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://www.areacucuta.com/los-cabos-el-paraiso-que-eligen-las-celebridades-para-pasar-sus-vacaciones-en-latinoamerica/', 'https://www.meganoticias.mx/los-cabos/noticia/gandhi-primera-libreria-y-papeleria-en-los-cabos/546944', 'https://www.bcsnoticias.mx/milagros-de-13-anos-esta-desaparecida-activan-protocolo-alba-en-los-cabos-para-encontrarla-1/', 'https://markets.businessinsider.com/news/stocks/the-coveted-group-receives-8-5-million-investment-for-east-cape-los-cabos-project-1033734506', 'https://travel.usnews.com/Cabo_San_Lucas_Mexico/Area_Map/', 'https://mexiconewsdaily.com/travel/los-cabos-tourism-trends-2024/', 'https://www.wunderground.com/weather/mx/cabo-san-lucas', 'https://cruiseindustrynews.com/cruise-news/2024/08/the-world-unveils-2025-journey-with-nearly-100-ports/']
