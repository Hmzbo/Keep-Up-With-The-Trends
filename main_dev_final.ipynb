# %% [markdown]
# # Keep Up  With The Trends

# %% [markdown]
# **Installation steps with conda**
#
# 1. conda create -n kuwtt pyton=3.10.14
# 2. pip install -r requirements.txt
# 3. pip install torch==2.3.1 --index-url https://download.pytorch.org/whl/cu118
# 4. [Download](https://ollama.com/download), Install & Run Ollama

# %%
# verify that CUDA is available

import torch

cuda_available = torch.cuda.is_available()
print(f"CUDA available: {cuda_available}")
# Out:
# CUDA available: True

# %%
# Import necessary libraries

import time
import json
import re
import requests
import pandas as pd
import xmltodict
from tqdm.notebook import tqdm
from duckduckgo_search import DDGS
from pprint import pprint

# %% [markdown]
# ## Scraping Trends Data

# %%
def fetch_and_parse_xml(url):
    try:
        # Fetch the XML data
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes
        xml_data = response.content

        # Parse the XML data and convert it to a dictionary
        data_dict = xmltodict.parse(xml_data)
        return data_dict

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the XML data: {e}")
    except xmltodict.expat.ExpatError as e:
        print(f"Error parsing the XML data: {e}")

# %%
# URL for the XML data
rss_xml_url_daily = 'https://trends.google.fr/trends/trendingsearches/daily/rss?geo=US'
rss_xml_url_realtime = 'https://trends.google.com/trending/rss?geo=US'

# Fetch, parse, and print the XML data
trends_dict = fetch_and_parse_xml(rss_xml_url_realtime)

pprint(trends_dict)
# Out:
# {'rss': {'@version': '2.0',
#          '@xmlns:atom': 'http://www.w3.org/2005/Atom',
#          '@xmlns:ht': 'https://trends.google.com/trending/rss',
#          'channel': {'atom:link': {'@href': 'https://trends.google.com/trending/rss?geo=US',
#                                    '@rel': 'self',
#                                    '@type': 'application/rss+xml'},
#                      'description': 'Recent searches',
#                      'item': [{'description': None,
#                                'ht:approx_traffic': '2000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRMRAO3Rs1UNQ0C7TFDSOBMiTkvfFLBw10cTCtQk51NgX4-y9nVkmvbEXLw3mw',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Marca.com',
#                                                  'ht:news_item_title': 'El '
#                                                                        'curioso '
#                                                                        'equipo '
#                                                                        'que '
#                                                                        'jugará '
#                                                                        'la FA '
#                                                                        'Cup '
#                                                                        'con el '
#                                                                        'antiguo '
#                                                                        'escudo '
#                                                                        'del '
#                                                                        'Atlético',
#                                                  'ht:news_item_url': 'https://www.marca.com/futbol/futbol-internacional/2024/08/29/66d0852eca4741621a8b458b.html'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQEjCXDNUTSlyfIq2NKIIBcS66jZAz7a32QAwJ0z8vR9X5_GncnlutkQ3GKe3E',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Marca.com',
#                                                  'ht:news_item_title': 'Athletic '
#                                                                        '- '
#                                                                        'Atlético '
#                                                                        'en '
#                                                                        'directo '
#                                                                        '| '
#                                                                        'LaLiga '
#                                                                        'EA '
#                                                                        'Sports '
#                                                                        'en '
#                                                                        'vivo '
#                                                                        'hoy',
#                                                  'ht:news_item_url': 'https://www.marca.com/futbol/laliga-ea-sports/athletic-atletico/2024/08/31/01_0101_20240831_174_175-directo.html'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSFltxvmGOUf2Rv0ibrDxfyt7R5HHcC7WBhS-NZfmohdel2rUybQaxOevrqz1Q',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Diario '
#                                                                         'AS',
#                                                  'ht:news_item_title': 'Una '
#                                                                        'final '
#                                                                        'en '
#                                                                        'agosto',
#                                                  'ht:news_item_url': 'https://as.com/futbol/primera/una-final-en-agosto-n/'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRMRAO3Rs1UNQ0C7TFDSOBMiTkvfFLBw10cTCtQk51NgX4-y9nVkmvbEXLw3mw',
#                                'ht:picture_source': 'Marca.com',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'athletic - atlético madrid'},
#                               {'description': None,
#                                'ht:approx_traffic': '2000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQxg8dOkQq8O3fVEfhRDLwBNeQ_1BO8RxB5i_AOW4pcB0I4HlqRkUwCeZXWEoQ',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Raiders '
#                                                                         'Wire',
#                                                  'ht:news_item_title': 'Antonio '
#                                                                        'Pierce '
#                                                                        'gives '
#                                                                        'update '
#                                                                        'on '
#                                                                        'Brock '
#                                                                        'Bowers '
#                                                                        'injury '
#                                                                        'status '
#                                                                        'for '
#                                                                        'Raiders '
#                                                                        'opener',
#                                                  'ht:news_item_url': 'https://raiderswire.usatoday.com/2024/08/29/antonio-pierce-update-brock-bowers-injury-status-las-vegas-raiders-season-opener-los-angeles-chargers/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSgowMh0uzr7kusRBP9XdNgE_WViZiJO7uxIRQe9EofAOHh-xA6KlXnPe-T1Fk',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Bleacher '
#                                                                         'Report',
#                                                  'ht:news_item_title': 'Fantasy '
#                                                                        'NFL '
#                                                                        'Rumors: '
#                                                                        "Raiders' "
#                                                                        'Brock '
#                                                                        'Bowers, '
#                                                                        "Giants' "
#                                                                        'Theo '
#                                                                        'Johnson '
#                                                                        'Eyed '
#                                                                        'for \n'
#                                                                        'Major '
#                                                                        'Roles',
#                                                  'ht:news_item_url': 'https://www.bleacherreport.com/articles/10133037-fantasy-nfl-rumors-raiders-brock-bowers-giants-theo-johnson-eyed-for-major-roles'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTUrDgVMetBte0gcS2HsZabDF2RRxwPlBWKQiw5p_atrnq_c2D_TjXRmR-wIjM',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Just '
#                                                                         'Blog '
#                                                                         'Baby',
#                                                  'ht:news_item_title': 'Antonio '
#                                                                        'Pierce '
#                                                                        'gives '
#                                                                        'key '
#                                                                        'injury '
#                                                                        'update '
#                                                                        'on '
#                                                                        'Brock '
#                                                                        'Bowers',
#                                                  'ht:news_item_url': 'https://justblogbaby.com/posts/antonio-pierce-gives-key-injury-update-on-brock-bowers'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQxg8dOkQq8O3fVEfhRDLwBNeQ_1BO8RxB5i_AOW4pcB0I4HlqRkUwCeZXWEoQ',
#                                'ht:picture_source': 'Raiders Wire',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'brock bowers'},
#                               {'description': None,
#                                'ht:approx_traffic': '1000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQs2-t_Sr6OwDzdEoIbzMYjZIQDcpJgvtG0iFbwwBx35xBd69tAMa5QaIvd7-w',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Los '
#                                                                         'Angeles '
#                                                                         'Times',
#                                                  'ht:news_item_title': 'Ready '
#                                                                        'or '
#                                                                        'not, '
#                                                                        'Stetson '
#                                                                        'Bennett '
#                                                                        'will '
#                                                                        'make '
#                                                                        'his '
#                                                                        'NFL '
#                                                                        'debut '
#                                                                        'as '
#                                                                        'Rams '
#                                                                        'No. '
#                                                                        '2 \n'
#                                                                        'quarterback',
#                                                  'ht:news_item_url': 'https://www.latimes.com/sports/rams/story/2024-08-29/rams-stetson-bennett-no-2-quarterback'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSgxko-Nw-Nvv3Q5WCo1Kl97g86JqkgaIgKBpxyvq5fuYGH8nifYEpZc8mm1r4',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Rams '
#                                                                         'Wire',
#                                                  'ht:news_item_title': 'Stetson '
#                                                                        'Bennett '
#                                                                        'was '
#                                                                        'initially '
#                                                                        'confused '
#                                                                        'about '
#                                                                        'sitting '
#                                                                        'out '
#                                                                        'final '
#                                                                        'preseason \n'
#                                                                        'game',
#                                                  'ht:news_item_url': 'https://theramswire.usatoday.com/2024/08/30/rams-stetson-bennett-backup-quarterback-sean-mcvay-preseason/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSyI7ojf9R77KSJf1yjDxTAcOgYBOxqgSqEbFM13uNHdQ6b95kC3yN-g-iRIug',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': '11Alive.com',
#                                                  'ht:news_item_title': 'Did '
#                                                                        'Stetson '
#                                                                        'Bennett '
#                                                                        'make '
#                                                                        'the '
#                                                                        'Rams '
#                                                                        'roster?',
#                                                  'ht:news_item_url': 'https://www.11alive.com/article/sports/nfl/did-stetson-bennett-make-rams-roster-nfl-cuts/85-47c85b3f-e4b0-409d-a971-85a37ad2b94a'}],
#                                'ht:picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQs2-t_Sr6OwDzdEoIbzMYjZIQDcpJgvtG0iFbwwBx35xBd69tAMa5QaIvd7-w',
#                                'ht:picture_source': 'Los Angeles Times',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'stetson bennett'},
#                               {'description': None,
#                                'ht:approx_traffic': '500+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNbKOS7c6V_Pw3008CAOuEs5DW4r8nTyEelNFUm6v8kPnUr_V8zOQSdtbuHMY',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'DawgNation',
#                                                  'ht:news_item_title': 'While '
#                                                                        'hype '
#                                                                        'around '
#                                                                        'KJ '
#                                                                        'Bolden '
#                                                                        'has '
#                                                                        'cooled, '
#                                                                        'Kirby '
#                                                                        'Smart '
#                                                                        'is '
#                                                                        'confident '
#                                                                        'he’ll '
#                                                                        'make \n'
#                                                                        'an '
#                                                                        'early '
#                                                                        'impact',
#                                                  'ht:news_item_url': 'https://www.dawgnation.com/football/kj-bolden-primed-make-an-immediate-impact-georgia-football-against-clemson-hes-sponge/P4FAG7PFMZH2VN6JT5TZN72LUA/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSNi4otQh0Eb0v21F6VXIemkXfXgg_UOYDrCdTQ9xrGHcSdJiTQtV9Fo5KIVWY',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'BVM '
#                                                                         'Sports',
#                                                  'ht:news_item_title': 'Rivals '
#                                                                        'Freshman '
#                                                                        'All-America '
#                                                                        'Defensive '
#                                                                        'Team: '
#                                                                        'Top '
#                                                                        '2024 '
#                                                                        'Talents',
#                                                  'ht:news_item_url': 'https://bvmsports.com/2024/08/28/rivals-freshman-all-america-defensive-team-top-2024-talents/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSn8HhAEGK8a-wFPrpiQuSSxhkmoIij-GhGV7tcr7yXgTM-BAXdClN7kdzToaU',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Yahoo '
#                                                                         'Sports',
#                                                  'ht:news_item_title': 'Rivals.com '
#                                                                        'Freshman '
#                                                                        'All-America '
#                                                                        'Team: '
#                                                                        'Defense',
#                                                  'ht:news_item_url': 'https://sports.yahoo.com/rivals-com-freshman-america-team-111902229.html'}],
#                                'ht:picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNbKOS7c6V_Pw3008CAOuEs5DW4r8nTyEelNFUm6v8kPnUr_V8zOQSdtbuHMY',
#                                'ht:picture_source': 'DawgNation',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'kj bolden'},
#                               {'description': None,
#                                'ht:approx_traffic': '1000+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRDm6fKQ5LJG1_07u_Qte563UQUMb7dfjhpDTIbY0LoTNHaib8Xil0081lO9Ls',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'ESPN',
#                                                  'ht:news_item_title': "Don't "
#                                                                        'be '
#                                                                        'surprised '
#                                                                        'if ... '
#                                                                        ': '
#                                                                        'Fantasy '
#                                                                        'predictions '
#                                                                        'for '
#                                                                        '2024',
#                                                  'ht:news_item_url': 'https://www.espn.com/fantasy/football/story/_/id/41032720/2024-fantasy-football-rankings-draft-picks-predictions-surprises'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQB0lG57P8MDzpZPkczwj-C9OLAN3RIF0KPb3B_sBCIRj-BLMqv1qlvbKIJuYA',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Bleacher '
#                                                                         'Report',
#                                                  'ht:news_item_title': 'Fantasy '
#                                                                        'Football '
#                                                                        '2024 '
#                                                                        'Cheat '
#                                                                        'Sheet: '
#                                                                        'Printable '
#                                                                        'Draft '
#                                                                        'Rankings '
#                                                                        'and '
#                                                                        'Sleepers '
#                                                                        'to \n'
#                                                                        'Target',
#                                                  'ht:news_item_url': 'https://bleacherreport.com/articles/10133743-fantasy-football-2024-cheat-sheet-printable-draft-rankings-and-sleepers-to-target'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTql8i2IYcESG8Y4vPdeoM3rlxw-Lkq9l9d0o7YudZ0-vo5KjfLni_wxA2O08I',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'NBC '
#                                                                         'Sports',
#                                                  'ht:news_item_title': 'Fantasy '
#                                                                        'Football '
#                                                                        '2024: '
#                                                                        'Rotoworld '
#                                                                        'staff '
#                                                                        'most '
#                                                                        'drafted '
#                                                                        'players',
#                                                  'ht:news_item_url': 'https://www.nbcsports.com/fantasy/football/news/fantasy-football-2024-rotoworld-staff-most-drafted-players'}],
#                                'ht:picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRDm6fKQ5LJG1_07u_Qte563UQUMb7dfjhpDTIbY0LoTNHaib8Xil0081lO9Ls',
#                                'ht:picture_source': 'ESPN',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'ladd mcconkey'},
#                               {'description': None,
#                                'ht:approx_traffic': '500+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKcsWUmQj-m5b5RwAWtKAYA8sAw28y2h2gTzP4D0OHFtmki-h53X1i86FsbUg',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Cincy '
#                                                                         'Jungle',
#                                                  'ht:news_item_title': 'Bengals '
#                                                                        'News '
#                                                                        '(8/31): '
#                                                                        'Kendall '
#                                                                        'Milton '
#                                                                        'a '
#                                                                        'Practice '
#                                                                        'Squad '
#                                                                        'Sleeper?',
#                                                  'ht:news_item_url': 'https://www.cincyjungle.com/2024/8/31/24232634/bengals-news-kendall-milton-practice-squad-sleeper'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTN3TL7kkQjXfVdkzrMWcHi0_MkGglthFSrBUEamguzL5une73eslxTeV9Wv9k',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Yahoo '
#                                                                         'Sports',
#                                                  'ht:news_item_title': 'Philadelphia '
#                                                                        'Eagles '
#                                                                        'release '
#                                                                        'former '
#                                                                        'Georgia '
#                                                                        'Bulldog '
#                                                                        'running '
#                                                                        'back',
#                                                  'ht:news_item_url': 'https://sports.yahoo.com/philadelphia-eagles-release-former-georgia-123056737.html'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcT_Ny0fQXtaxA0uVtrL--pHAEgaF7hW18DCBpnWp6BnlAjLgTSjvsuaDYqAng8',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Athlon '
#                                                                         'Sports',
#                                                  'ht:news_item_title': 'Former '
#                                                                        'Star '
#                                                                        'Georgia '
#                                                                        'RB '
#                                                                        'Signs '
#                                                                        'With '
#                                                                        'Cincinnati '
#                                                                        'Bengals',
#                                                  'ht:news_item_url': 'https://athlonsports.com/nfl/former-star-georgia-rb-kendall-milton-signs-with-cincinnati-bengals'}],
#                                'ht:picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKcsWUmQj-m5b5RwAWtKAYA8sAw28y2h2gTzP4D0OHFtmki-h53X1i86FsbUg',
#                                'ht:picture_source': 'Cincy Jungle',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'kendall milton'},
#                               {'description': None,
#                                'ht:approx_traffic': '500+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTPcn70kXMw2cx4CgXLve-BF-lw6O3-TQL60zBQkMBgqwd8azt0qq0-8mseS00',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Eagles '
#                                                                         'Wire',
#                                                  'ht:news_item_title': 'Eagles '
#                                                                        'rookie '
#                                                                        'RB '
#                                                                        'Will '
#                                                                        'Shipley '
#                                                                        'switches '
#                                                                        'jersey '
#                                                                        'number',
#                                                  'ht:news_item_url': 'https://theeagleswire.usatoday.com/2024/08/29/eagles-news-will-shipley-jersey-number-switch-josh-jobe-waived/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTohYFGMGucr0r9_w6iQPXgznxLu11hW5hCh0E2UFpwb6ayZQWD7hHUdbhPd6Q',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Bleeding '
#                                                                         'Green '
#                                                                         'Nation',
#                                                  'ht:news_item_title': 'Eagles '
#                                                                        'jersey '
#                                                                        'number '
#                                                                        'updates: '
#                                                                        'New '
#                                                                        'looks '
#                                                                        'for '
#                                                                        'Quinyon '
#                                                                        'Mitchell, '
#                                                                        'Will '
#                                                                        'Shipley, \n'
#                                                                        'and '
#                                                                        'other '
#                                                                        'players',
#                                                  'ht:news_item_url': 'https://www.bleedinggreennation.com/2024/8/29/24231617/eagles-jersey-number-updates-new-looks-quinyon-mitchell-will-shipley-jahan-dotson-jack-stoll-players'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTgotwqdOcAYOoO2tOhXSUKaNQH_iJyTSTE8hfcANiXS_kwD6HOYzGx1jZedgo',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'NBC '
#                                                                         'Sports '
#                                                                         'Philadelphia',
#                                                  'ht:news_item_title': 'Eagles '
#                                                                        'practice '
#                                                                        'notes: '
#                                                                        'Rookie '
#                                                                        'in a '
#                                                                        'new '
#                                                                        'number, '
#                                                                        'injury '
#                                                                        'updates',
#                                                  'ht:news_item_url': 'https://www.nbcsportsphiladelphia.com/nfl/philadelphia-eagles/eagles-practice-notes-rookie-in-a-new-number-injury-updates/611102/'}],
#                                'ht:picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTPcn70kXMw2cx4CgXLve-BF-lw6O3-TQL60zBQkMBgqwd8azt0qq0-8mseS00',
#                                'ht:picture_source': 'Eagles Wire',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'will shipley'},
#                               {'description': None,
#                                'ht:approx_traffic': '500+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRmu9iaYwVczyogbRP3uzKVcuqmWx7rnGP-tP04WPUQTj9QV4vrNdTaRGo7l1g',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'USA '
#                                                                         'Today',
#                                                  'ht:news_item_title': 'Who is '
#                                                                        'the '
#                                                                        'biggest '
#                                                                        'player '
#                                                                        'on '
#                                                                        'Georgia '
#                                                                        "football's "
#                                                                        'roster',
#                                                  'ht:news_item_url': 'https://ugawire.usatoday.com/2024/08/31/biggest-player-georgia-football-roster-offensive-line/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSfLen8SU99wH8j1ob_hW82nHvWffW1HSeSwSDFxbvK9A45eLm68f_k0zA0Bhw',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'USA '
#                                                                         'Today',
#                                                  'ht:news_item_title': 'Georgia '
#                                                                        'vs '
#                                                                        'Clemson '
#                                                                        'live '
#                                                                        'updates: '
#                                                                        'Bulldogs-Tigers '
#                                                                        'score, '
#                                                                        'highlights, \n'
#                                                                        'analysis '
#                                                                        'and '
#                                                                        'more',
#                                                  'ht:news_item_url': 'https://www.usatoday.com/story/sports/ncaaf/2024/08/31/georgia-clemson-score-live-updates-highlights/74986333007/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQY1F4bqK7NORwAHas1ZaMPA6luOn3nu2XVwLRNcmjeX9UnDlSZujfwm0DXHeY',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Sports '
#                                                                         'Illustrated',
#                                                  'ht:news_item_title': 'College '
#                                                                        'Gameday '
#                                                                        'Crew '
#                                                                        'Makes '
#                                                                        'Georgia '
#                                                                        'vs '
#                                                                        'Clemson '
#                                                                        'Picks',
#                                                  'ht:news_item_url': 'https://www.si.com/college/georgia/football/college-gameday-crew-makes-georgia-vs-clemson-picks-01j6mda9c49g'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRmu9iaYwVczyogbRP3uzKVcuqmWx7rnGP-tP04WPUQTj9QV4vrNdTaRGo7l1g',
#                                'ht:picture_source': 'USA Today',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'georgia football roster'},
#                               {'description': None,
#                                'ht:approx_traffic': '500+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQ5DVMXjQlQSOmkx8yBbQJtr_JbbnAieW5SvMAjQvmF2klinQ_i2eDGcnfQSow',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Daily '
#                                                                         'Express',
#                                                  'ht:news_item_title': 'US '
#                                                                        'Open '
#                                                                        'finalist '
#                                                                        'gives '
#                                                                        'tennis '
#                                                                        'legend '
#                                                                        'telling-off '
#                                                                        'for '
#                                                                        "'stereotyping "
#                                                                        'based '
#                                                                        'on \n'
#                                                                        "gender'",
#                                                  'ht:news_item_url': 'https://www.express.co.uk/sport/tennis/1942610/US-Open-Ons-Jabeur-Chris-Evert-Karolina-Muchova'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTfhzx29goBcxODD9_AnLA6aaV8DN2SmG5nvBtxcn6J-9MPb2oESGV7Y-o6JoA',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Tennis365',
#                                                  'ht:news_item_title': 'Tennis '
#                                                                        'legend '
#                                                                        'Chris '
#                                                                        'Evert '
#                                                                        'apologises '
#                                                                        'for '
#                                                                        "'she "
#                                                                        'plays '
#                                                                        'like a '
#                                                                        "guy' "
#                                                                        'comment \n'
#                                                                        'after '
#                                                                        'being '
#                                                                        'called '
#                                                                        'out by '
#                                                                        'Ons '
#                                                                        'Jabeur',
#                                                  'ht:news_item_url': 'https://www.tennis365.com/news/tennis-legend-chris-evert-apologises-she-plays-like-a-guy-comment-ons-jabeur'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTeovS7G-KY7KoIOXMbKSpTAC1ZyJ5-LV2K-oQBNOQ7FagLUtCcR2tE4oozoUY',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'MSN',
#                                                  'ht:news_item_title': 'Nick '
#                                                                        'Kyrgios '
#                                                                        'joins '
#                                                                        'Ons '
#                                                                        'Jabeur '
#                                                                        'in '
#                                                                        'taking '
#                                                                        'a dig '
#                                                                        'at '
#                                                                        'Chris '
#                                                                        'Evert '
#                                                                        'for '
#                                                                        'comparing \n'
#                                                                        'Karolina '
#                                                                        'Muchova '
#                                                                        'to '
#                                                                        "men's "
#                                                                        'tennis '
#                                                                        'players '
#                                                                        'at US '
#                                                                        'Open',
#                                                  'ht:news_item_url': 'https://www.msn.com/en-us/sports/tennis/nick-kyrgios-joins-ons-jabeur-in-taking-a-dig-at-chris-evert-for-comparing-karolina-muchova-to-men-s-tennis-players-at-us-open/ar-AA1pLuHf'}],
#                                'ht:picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQ5DVMXjQlQSOmkx8yBbQJtr_JbbnAieW5SvMAjQvmF2klinQ_i2eDGcnfQSow',
#                                'ht:picture_source': 'Daily Express',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'muchova'},
#                               {'description': None,
#                                'ht:approx_traffic': '200+',
#                                'ht:news_item': [{'ht:news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNIDyGHrjdvXMBe6inFbbDiQ4BsUM98KL5l8v4YARZ9hbVp80fhxNkA7NAkzg',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Journal '
#                                                                         '& '
#                                                                         'Courier',
#                                                  'ht:news_item_title': 'Purdue '
#                                                                        'football '
#                                                                        'vs. '
#                                                                        'Indiana '
#                                                                        'State: '
#                                                                        'Scout '
#                                                                        'report, '
#                                                                        'prediction',
#                                                  'ht:news_item_url': 'https://www.jconline.com/story/sports/college/purdue/football/2024/08/30/predicting-the-outcome-of-saturdays-purdue-vs-indiana-state-game/74918957007/'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRcSctzCeloYFHXe2ZUdzFR3zaW5TV8Fd4SH2cuMiKBRqOobOzkvmy6_kmFQHU',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Rivals.com: '
#                                                                         'Rivals '
#                                                                         'Football '
#                                                                         '& '
#                                                                         'Basketball '
#                                                                         'Recruiting',
#                                                  'ht:news_item_title': 'Purdue '
#                                                                        'Boilermakers '
#                                                                        'Football '
#                                                                        '& '
#                                                                        'Basketball '
#                                                                        'Recruiting '
#                                                                        '- '
#                                                                        'Purdue '
#                                                                        'vs. '
#                                                                        'Indiana \n'
#                                                                        'State: '
#                                                                        'Three '
#                                                                        'Keys '
#                                                                        'to '
#                                                                        'Victory',
#                                                  'ht:news_item_url': 'https://purdue.rivals.com/news/purdue-vs-indiana-state-three-keys-to-victory'},
#                                                 {'ht:news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQWickOZkKNfsP4Dg88AFin4hJUCuzdsPGIg7t36mJIKq6bfm8pOJ0D7tz_L4Y',
#                                                  'ht:news_item_snippet': None,
#                                                  'ht:news_item_source': 'Purdue '
#                                                                         'Exponent',
#                                                  'ht:news_item_title': 'Traffic '
#                                                                        'will '
#                                                                        'be '
#                                                                        'affected '
#                                                                        'by '
#                                                                        'game '
#                                                                        'day',
#                                                  'ht:news_item_url': 'https://www.purdueexponent.org/campus/article_f7095db8-66e1-11ef-aaa6-6ba5adfc0eb2.html'}],
#                                'ht:picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNIDyGHrjdvXMBe6inFbbDiQ4BsUM98KL5l8v4YARZ9hbVp80fhxNkA7NAkzg',
#                                'ht:picture_source': 'Journal & Courier',
#                                'link': 'https://trends.google.com/trending/rss?geo=US',
#                                'pubDate': 'Sat, 31 Aug 2024 09:10:00 -0700',
#                                'title': 'indiana state football'}],
#                      'link': 'https://trends.google.com/trending/rss?geo=US',
#                      'title': 'Daily Search Trends'}}}

# %%
# create google trends dataframe

google_trends_dict = {"trend_kws":[], "traffic":[], "pubDate":[], "url":[], "title":[]}

for trend in trends_dict['rss']['channel']['item']:
    google_trends_dict['trend_kws'].append(trend['title'])
    google_trends_dict['traffic'].append(trend['ht:approx_traffic'])
    google_trends_dict['pubDate'].append(trend['pubDate'])
    google_trends_dict['url'].append([news_item['ht:news_item_url'] for news_item in trend['ht:news_item']])
    google_trends_dict['title'].append([news_item['ht:news_item_title'] for news_item in trend['ht:news_item']])

google_trends_df = pd.DataFrame(google_trends_dict)

# %%
# clean data

google_trends_df["title"] = google_trends_df["title"].map(lambda links: [link.replace("&#39;", "'") for link in links])

# %%
google_trends_df.head()
# Out:
#                     trend_kws traffic                          pubDate  \
# 0  athletic - atlético madrid   2000+  Sat, 31 Aug 2024 09:10:00 -0700
# 1                brock bowers   2000+  Sat, 31 Aug 2024 09:10:00 -0700
# 2             stetson bennett   1000+  Sat, 31 Aug 2024 09:10:00 -0700
# 3                   kj bolden    500+  Sat, 31 Aug 2024 09:10:00 -0700
# 4               ladd mcconkey   1000+  Sat, 31 Aug 2024 09:10:00 -0700
#
#                                                  url  \
# 0  [https://www.marca.com/futbol/futbol-internaci...
# 1  [https://raiderswire.usatoday.com/2024/08/29/a...
# 2  [https://www.latimes.com/sports/rams/story/202...
# 3  [https://www.dawgnation.com/football/kj-bolden...
# 4  [https://www.espn.com/fantasy/football/story/_...
#
#                                                title
# 0  [El curioso equipo que jugará la FA Cup con el...
# 1  [Antonio Pierce gives update on Brock Bowers i...
# 2  [Ready or not, Stetson Bennett will make his N...
# 3  [While hype around KJ Bolden has cooled, Kirby...
# 4  [Don't be surprised if ... : Fantasy predictio...

# %%
# define the list of domains to skip

domains_skip_list = ["msn.com", "washingtonpost.com"]

# %%
# remove urls that contain domains in domains_skip_list

for i in range(google_trends_df.shape[0]):
    for j, url in enumerate(google_trends_df.loc[i,"url"]):
        if any(domain in url for domain in domains_skip_list):
            _ = google_trends_df.loc[i,"url"].pop(j)
            _ = google_trends_df.loc[i,"title"].pop(j)

# %%
google_trends_df.head(20)
# Out:
#                     trend_kws traffic                          pubDate  \
# 0  athletic - atlético madrid   2000+  Sat, 31 Aug 2024 09:10:00 -0700
# 1                brock bowers   2000+  Sat, 31 Aug 2024 09:10:00 -0700
# 2             stetson bennett   1000+  Sat, 31 Aug 2024 09:10:00 -0700
# 3                   kj bolden    500+  Sat, 31 Aug 2024 09:10:00 -0700
# 4               ladd mcconkey   1000+  Sat, 31 Aug 2024 09:10:00 -0700
# 5              kendall milton    500+  Sat, 31 Aug 2024 09:10:00 -0700
# 6                will shipley    500+  Sat, 31 Aug 2024 09:10:00 -0700
# 7     georgia football roster    500+  Sat, 31 Aug 2024 09:10:00 -0700
# 8                     muchova    500+  Sat, 31 Aug 2024 09:10:00 -0700
# 9      indiana state football    200+  Sat, 31 Aug 2024 09:10:00 -0700
#
#                                                  url  \
# 0  [https://www.marca.com/futbol/futbol-internaci...
# 1  [https://raiderswire.usatoday.com/2024/08/29/a...
# 2  [https://www.latimes.com/sports/rams/story/202...
# 3  [https://www.dawgnation.com/football/kj-bolden...
# 4  [https://www.espn.com/fantasy/football/story/_...
# 5  [https://www.cincyjungle.com/2024/8/31/2423263...
# 6  [https://theeagleswire.usatoday.com/2024/08/29...
# 7  [https://ugawire.usatoday.com/2024/08/31/bigge...
# 8  [https://www.express.co.uk/sport/tennis/194261...
# 9  [https://www.jconline.com/story/sports/college...
#
#                                                title
# 0  [El curioso equipo que jugará la FA Cup con el...
# 1  [Antonio Pierce gives update on Brock Bowers i...
# 2  [Ready or not, Stetson Bennett will make his N...
# 3  [While hype around KJ Bolden has cooled, Kirby...
# 4  [Don't be surprised if ... : Fantasy predictio...
# 5  [Bengals News (8/31): Kendall Milton a Practic...
# 6  [Eagles rookie RB Will Shipley switches jersey...
# 7  [Who is the biggest player on Georgia football...
# 8  [US Open finalist gives tennis legend telling-...
# 9  [Purdue football vs. Indiana State: Scout repo...

# %%
# get trends related news articles from ddg web search

trends_news = []
for trend_kw in tqdm(google_trends_df.trend_kws.to_list()):
    results = DDGS().news(keywords=trend_kw, region="wt-wt", safesearch="moderate", max_results=15)
    filtered_results = [res for res in results if not any(domain in res['url'] for domain in domains_skip_list)]
    filtered_results = list(map(lambda d: {'trend_kws':trend_kw, **d}, filtered_results[:5]))
    trends_news.extend(filtered_results)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
# create ddg news articles dataframe

trends_ddg_news_df = pd.DataFrame(trends_news)
trends_ddg_news_df.head(10)
# Out:
#                     trend_kws                       date  \
# 0  athletic - atlético madrid  2024-08-31T12:24:00+00:00
# 1  athletic - atlético madrid  2024-08-31T14:47:00+00:00
# 2  athletic - atlético madrid  2024-08-30T17:49:00+00:00
# 3  athletic - atlético madrid  2024-08-28T22:56:00+00:00
# 4  athletic - atlético madrid  2024-08-30T16:30:00+00:00
#
#                                                title  \
# 0  Athletic Bilbao coach Valverde ready for "ambi...
# 1  Diego Simeone Defends Atletico Madrid During T...
# 2  Atletico boss Simeone in terse mood before Bil...
# 3  Atletico Madrid struggles to find the net in 0...
# 4  'The team is complete' - Simeone pulls Atletic...
#
#                                                 body  \
# 0  Athletic Bilbao coach Ernesto Valverde expects...
# 1  who was speaking ahead of their trip to face A...
# 2                                                                      Reuters
# 3                                                             Associated Press
# 4  https://media.zenfs.com/en/sempremilan_article...             Yahoo! Sports
# 5  https://s.yimg.com/ny/api/res/1.2/99MQf5fIf2Aw...             Yahoo! Sports
# 6  https://bloximages.newyork1.vip.townnews.com/d...             Daily Journal
# 7  https://www.reviewjournal.com/wp-content/uploa...  Las Vegas Review-Journal
# 8                                                           Larry Brown Sports
# 9                                                           Sports Illustrated

# %%
# update google trends dataframe with ddg news articles urls and titles

for i, trend in enumerate(google_trends_df.trend_kws):
    url_list = trends_ddg_news_df[trends_ddg_news_df["trend_kws"]==trend]['url'].to_list()
    title_list = trends_ddg_news_df[trends_ddg_news_df["trend_kws"]==trend]['title'].to_list()
    google_trends_df.loc[i, "url"].extend(url_list)
    google_trends_df.loc[i, "title"].extend(title_list)

# %%
google_trends_df.title[0]
# Out:
# ['El curioso equipo que jugará la FA Cup con el antiguo escudo del Atlético',
#  'Athletic - Atlético en directo | LaLiga EA Sports en vivo hoy',
#  'Una final en agosto',
#  'Athletic Bilbao coach Valverde ready for "ambitious" Atletico Madrid',
#  'Diego Simeone Defends Atletico Madrid During Tense Press Conference',
#  'Atletico boss Simeone in terse mood before Bilbao clash',
#  'Atletico Madrid struggles to find the net in 0-0 draw with Espanyol in Spanish league',
#  "'The team is complete' - Simeone pulls Atletico Madrid out of Bennacer race"]

# %%
google_trends_df.url[0]
# Out:
# ['https://www.marca.com/futbol/futbol-internacional/2024/08/29/66d0852eca4741621a8b458b.html',
#  'https://www.marca.com/futbol/laliga-ea-sports/athletic-atletico/2024/08/31/01_0101_20240831_174_175-directo.html',
#  'https://as.com/futbol/primera/una-final-en-agosto-n/',
#  'https://www.tribalfootball.com/article/soccer-laliga-athletic-bilbao-coach-valverde-ready-for-ambitious-atletico-madrid-897eb9f4-53dc-4621-9ace-09f272fdc9e9',
#  'https://www.outlookindia.com/sports/football/diego-simeone-defends-atletico-madrid-during-tense-press-conference',
#  'https://www.reuters.com/sports/soccer/atletico-boss-simeone-terse-mood-before-bilbao-clash-2024-08-30/',
#  'https://apnews.com/article/atletico-madrid-espanyol-spanish-league-score-46eaa47c28290b7454ecc76ebdcf5d36',
#  'https://sports.yahoo.com/team-complete-simeone-pulls-atletico-163000180.html']

# %% [markdown]
# ## Performing RAG (Retrieval-Augmented Generation)

# %%
# import libraries for rag with langchain

from langchain_community.document_loaders import SeleniumURLLoader, UnstructuredURLLoader, WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel
from langchain_core.utils.function_calling import convert_to_openai_tool
from langchain_core.runnables import RunnableLambda
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# define embedding model
embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# define llm
llm = ChatOllama(
    model="llama3.1",
    temperature=0.2,
    keep_alive="2m",
    repeat_penalty=1.03,
    # other params...
)


# define prompt template
prompt_template = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            You are a helpful assistant that specializes in article summarization.
            Your task is to summarize a given text article and generate a title for it.
            If the provided article doesn't contain coherent and meaningful content, just return an empty response.
            """,
        ),
        ("human", "Article: {article}"),
    ]
)


# define output schema for llm
class SummmaryWithTitle(BaseModel):
    '''Article summary and title.'''
    title: str
    summary: str

dict_schema = convert_to_openai_tool(SummmaryWithTitle)
structured_output_llm = llm.with_structured_output(dict_schema)
# Out:
# c:\Users\mlwit\.conda\envs\kuwtt\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# define helper functions

def url_loader(url_list:list[str], loader_type:str="Unstructured"):
    if loader_type == "Unstructured":
        unstruct_loader = UnstructuredURLLoader(url_list)
        data = unstruct_loader.load()
    elif loader_type == "Selenium":
        sele_loader = SeleniumURLLoader(url_list)
        driver = sele_loader._get_driver()
        try:
            data = sele_loader.load()
        finally:
            driver.close()
            driver.quit()
    elif loader_type == "Base":
        header_template = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        base_loader = WebBaseLoader(url_list, header_template=header_template)
        data = base_loader.load()
    else:
        raise ValueError(f"Loader type {loader_type} not supported.")
    return data


def rec_splitter(url_doc_list:list):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=400,
                                                   chunk_overlap=50,
                                                   add_start_index=True)
    all_splits = text_splitter.split_documents(url_doc_list)
    return all_splits


def reteived_docs_parser(ret_doc_list:list):
    ret_article = "\n".join([doc.page_content for doc in ret_doc_list])
    ret_article = ret_article.replace('\n\n', '. ')
    ret_article_sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<![A-Z][a-z][A-Z]\.)(?<=\.|\?|!|\n)\s*', ret_article)
    ret_article_meaningful_sentences = [s for s in ret_article_sentences if len(s.split()) > 5]
    meaningful_ret_article = '\n'.join(ret_article_meaningful_sentences)
    return meaningful_ret_article

reteived_docs_parser_runnable = RunnableLambda(reteived_docs_parser)

# %%
# define functions to run the rag pipeline

def run_rag_chain_once(trend, google_df, ddg_df, embeddings_model, reteived_docs_parser_runnable, prompt_template, structured_output_llm):
    print("# Starting RAG pipeline")
    start = time.time()

    print("## Scraping Articles")
    df_trend = google_df[google_df["trend_kws"]==trend]
    url_list = df_trend['url'].iloc[0]
    print(url_list)
    try:
        url_docs = url_loader(url_list, "Base")
        if len(" ".join([doc.page_content for doc in url_docs])) < 5000:
            print("Using UnstructuredLoader")
            url_docs = url_loader(url_list, "Unstructured")
    except Exception as e:
        print("Exception BaseURLLoader:", e)
        print("Using UnstructuredLoader")
        url_docs = url_loader(url_list, "Unstructured")

        
    for doc in url_docs:
        if (doc.page_content == "") & (doc.metadata["source"] in ddg_df.url.to_list()):
            article_body_index = ddg_df['url'].to_list().index(doc.metadata["source"])
            doc.page_content += ddg_df['body'][article_body_index]
    scraping_checkpoint = time.time()
    scraping_dur = scraping_checkpoint - start

    print("## Creating FAISS vectorstore")
    splits_docs = rec_splitter(url_docs)
    faiss_db = FAISS.from_documents(splits_docs, embeddings_model)
    faiss_retriever = faiss_db.as_retriever(search_type="similarity",
                                search_kwargs={'k': 5})
    faiss_checkpoint = time.time()
    faiss_dur = faiss_checkpoint - scraping_checkpoint

    print("## Performing RAG")
    ret_query = '\n'.join(df_trend['title'].iloc[0])
    rag_chain = (faiss_retriever
                    | { "article": reteived_docs_parser_runnable }
                    | prompt_template
                    | structured_output_llm)
    rag_results = rag_chain.invoke(ret_query)
    end = time.time()
    chain_dur = end - faiss_checkpoint
    print(f"Scrape: {scraping_dur}, Faiss: {faiss_dur}, Chain: {chain_dur}")
    return rag_results


def run_rag_chain_loop(google_df, ddg_df, embeddings_model, reteived_docs_parser_runnable, prompt_template, structured_output_llm):

    results={"Trend_kws":[], "Title":[], "Summary":[]}
    #trend_kws = ddg_news_df.trend_kws.value_counts().index.to_list()
    trend_kws = google_df.trend_kws.to_list()

    for i, trend_kw in tqdm(enumerate(trend_kws), total=len(trend_kws)):
        print(f"Trend number {i+1} of {len(trend_kws)}")
        if google_df[google_df["trend_kws"]==trend_kw]['url'].iloc[0]:
            rag_results = run_rag_chain_once(trend_kw, google_df, ddg_df, embeddings_model, reteived_docs_parser_runnable, prompt_template, structured_output_llm)
        else:
            rag_results = {'title':trend_kw, 'summary':'No enough information yet!'}
        print(f"""### Trend Keyword: {trend_kw}\n ### Title: {rag_results['title']}\n ### Summary: {rag_results['summary']}\n\n""")
        results['Trend_kws'].append(trend_kw)
        results['Title'].append(rag_results['title'])
        results['Summary'].append(rag_results['summary'])
        
    return results

# %%
# test the rag pipeline

results = run_rag_chain_loop(google_trends_df, trends_ddg_news_df, embeddings_model, reteived_docs_parser_runnable, prompt_template, structured_output_llm)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Trend number 1 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://www.marca.com/futbol/futbol-internacional/2024/08/29/66d0852eca4741621a8b458b.html', 'https://www.marca.com/futbol/laliga-ea-sports/athletic-atletico/2024/08/31/01_0101_20240831_174_175-directo.html', 'https://as.com/futbol/primera/una-final-en-agosto-n/', 'https://www.tribalfootball.com/article/soccer-laliga-athletic-bilbao-coach-valverde-ready-for-ambitious-atletico-madrid-897eb9f4-53dc-4621-9ace-09f272fdc9e9', 'https://www.outlookindia.com/sports/football/diego-simeone-defends-atletico-madrid-during-tense-press-conference', 'https://www.reuters.com/sports/soccer/atletico-boss-simeone-terse-mood-before-bilbao-clash-2024-08-30/', 'https://apnews.com/article/atletico-madrid-espanyol-spanish-league-score-46eaa47c28290b7454ecc76ebdcf5d36', 'https://sports.yahoo.com/team-complete-simeone-pulls-atletico-163000180.html']
# ## Creating FAISS vectorstore
# c:\Users\mlwit\.conda\envs\kuwtt\lib\site-packages\transformers\models\bert\modeling_bert.py:439: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# ## Performing RAG
# Scrape: 19.020139455795288, Faiss: 1.300205945968628, Chain: 16.166972398757935
# ### Trend Keyword: athletic - atlético madrid
#  ### Title: El curioso equipo que jugará la FA Cup con el antiguo escudo del Atlético
#  ### Summary: The article discusses the upcoming match between Athletic and Atletico Madrid in the FA Cup, highlighting their past rivalry and Atletico's current struggles in LaLiga EA Sports. It also mentions the unique relationship between the two teams, with Athletic having a strong record against Atletico since Diego Simeone took over in 2011.
#
#
# Trend number 2 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://raiderswire.usatoday.com/2024/08/29/antonio-pierce-update-brock-bowers-injury-status-las-vegas-raiders-season-opener-los-angeles-chargers/', 'https://www.bleacherreport.com/articles/10133037-fantasy-nfl-rumors-raiders-brock-bowers-giants-theo-johnson-eyed-for-major-roles', 'https://justblogbaby.com/posts/antonio-pierce-gives-key-injury-update-on-brock-bowers', 'https://sports.yahoo.com/antonio-pierce-feels-really-good-175534809.html?fr=sycsrp_catchall', 'https://www.djournal.com/sports/national/raiders-
# ## Creating FAISS vectorstore
# ## Performing RAG
# Scrape: 15.873084306716919, Faiss: 0.347095251083374, Chain: 8.7266366481781
# ### Trend Keyword: kj bolden
#  ### Title: Georgia Football Prepares for Preseason
#  ### Summary: Georgia football coach Kirby Smart expects a less aggressive camp due to the team’s stout schedule and length of season. The defense has several key players returning, including consensus preseason All-Americans Mykel Williams and Malaki Starks. However, the team is also dealing with changes in the secondary and the absence of some key players, including Trevor Etienne.
#
#
# Trend number 5 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://www.espn.com/fantasy/football/story/_/id/41032720/2024-fantasy-football-rankings-draft-picks-predictions-surprises', 'https://bleacherreport.com/articles/10133743-fantasy-football-2024-cheat-sheet-printable-draft-rankings-and-sleepers-to-target', 'https://www.nbcsports.com/fantasy/football/news/fantasy-football-2024-rotoworld-staff-most-drafted-players', 'https://www.cbssports.com/college-football/news/georgia-vs-clemson-live-stream-where-to-watch-tv-channel-game-odds-spread-prediction-picks/', 'https://theclemsoninsider.com/2024/08/30/priesters-preview-no-1-georgia-vs-no-14-clemson/', 'https://www.cbssports.com/fantasy/football/news/the-ultimate-fantasy-football-wide-receiver-preview-sleepers-breakouts-busts-targets-and-more/', 'https://www.totalprosports.com/nfl/ranking-all-32-nfl-teams-top-wide-receivers-for-the-2024-season-from-worst-to-first/', 'https://athlonsports.com/college-football/josh-pate-breaks-down-the-game-of-the-college-football-saturday-clemson-versus-georgia']
# ## Creating FAISS vectorstore
# ## Performing RAG
# Scrape: 22.04766273498535, Faiss: 0.5842783451080322, Chain: 8.559484720230103
# ### Trend Keyword: ladd mcconkey
#  ### Title: Fantasy Football 2024 Cheat Sheet: Printable Draft Rankings and Sleepers to Target
#  ### Summary: The article discusses fantasy football predictions, expectations, and surprises for the 2024 season. It provides a cheat sheet with printable draft rankings and sleepers to target. The article also includes information on wide receiver preview, sleepers, busts, and breakouts for the 2024 season.
#
#
# Trend number 6 of 10
# # Starting RAG pipeline
# ## Scraping Articles
# ['https://www.cincyjungle.com/2024/8/31/24232634/bengals-news-kendall-milton-practice-squad-sleeper', 'https://sports.yahoo.com/philadelphia-eagles-release-former-georgia-123056737.html', 'https://athlonsports.com/nfl/former-star-georgia-rb-kendall-milton-signs-with-cincinnati-bengals', 'https://wtop.com/prince-georges-county/2024/08/completing-bucket-list-nearly-caused-md-paddleboarder-to-kick-the-bucket/', 'https://ugawire.usatoday.com/2024/08/28/philadelphia-eagles-release-georgia-running-back-kendall-milton/', 'https://www.al.com/sports/2024/08/georgia-running-back-trevor-etienne-wont-play-vs-clemson-reports-say.html', 'https://local12.com/sports/bengals/bengals-resign-veteran-running-back-place-rookie-injured-reserve-trayveon-williams-mckinnley-jackson-nfl-cincinnati-fantasy-practice-squad', 'https://www.timesfreepress.com/news/2024/aug/30/no-1-georgia-vs-no-14-clemson-will-renew-off-and/']
